# %% [markdown]
# <a href="https://colab.research.google.com/github/votanluan/BAITAP_AI/blob/main/FOOD_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import cv2
import os
from os import listdir
from numpy import asarray
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.layers import Dense,Activation,BatchNormalization, Dropout, LSTM, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop, SGD
from keras.utils import np_utils
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
folder1 = '/content/drive/MyDrive/data_train/banh_beo'
folder2 = '/content/drive/MyDrive/data_train/banh_bot_loc'
folder3 = '/content/drive/MyDrive/data_train/banh_trang_nuong'
folder4 = '/content/drive/MyDrive/data_train/bap_xao'
folder5 = '/content/drive/MyDrive/data_train/bun_bo_hue'
folder6 = '/content/drive/MyDrive/data_train/chao_long'
folder7 = '/content/drive/MyDrive/data_train/mi_quang'
folder8 = '/content/drive/MyDrive/data_train/xoai_lac'
folder9 = '/content/drive/MyDrive/data_train/bun_dau_mam_tom'
folder10 = '/content/drive/MyDrive/data_train/goi_cuon'
photos, labels = list(), list()
for file in listdir(folder1):
  photo = load_img(folder1+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(0) 
for file in listdir(folder2):
  photo = load_img(folder2+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)               
  labels.append(1) 
for file in listdir(folder3):
  photo = load_img(folder3+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(2) 
for file in listdir(folder4):
  photo = load_img(folder4+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(3) 
for file in listdir(folder5):
  photo = load_img(folder5+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(4) 
for file in listdir(folder6):
  photo = load_img(folder6+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(5) 
for file in listdir(folder7):
  photo = load_img(folder7+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(6) 
for file in listdir(folder8):
  photo = load_img(folder8+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(7) 
for file in listdir(folder9):
  photo = load_img(folder9+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(8) 
for file in listdir(folder10):
  photo = load_img(folder10+'/'+file, target_size=(150,150))
  photo = img_to_array(photo)
  photos.append(photo)              
  labels.append(9) 
photos = asarray(photos)           
labels = asarray(labels)            
class_name = ['bánh bèo','bánh bột lộc','bánh tráng nướng','bắp xào','bún bò huế','cháo lòng','Tmì quảng','xoài lắc','bún đậu mắn tôm','gỏi cuốn']  
print(photos.shape, labels, class_name)
# Out:
# (6822, 150, 150, 3) [0 0 0 ... 9 9 9] ['bánh bèo', 'bánh bột lộc', 'bánh tráng nướng', 'bắp xào', 'bún bò huế', 'cháo lòng', 'Tmì quảng', 'xoài lắc', 'bún đậu mắn tôm', 'gỏi cuốn']

# %%
x_train, x_test, y_train, y_test = train_test_split(photos, labels, test_size=0.25, random_state=5)   #tạo dữ liệu train 75% và test 25%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (5116, 150, 150, 3) (1706, 150, 150, 3)
# (5116,) (1706,)

# %%
x_train_show = x_train.astype(int)            
import matplotlib.pyplot as plt
from matplotlib.image import imread
for i in range(9):
  plt.subplot(330+i+1)
  plt.imshow(x_train_show[i])
plt.show()

# %%
x_train/=255
x_test/=255
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same',))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same',))
model.add(MaxPooling2D((2,2)))

# %%
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))  #Dense la full connected 
model.add(Dense(10, activation='Softmax'))
opt = SGD(lr=0.01, momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy',  metrics=['accuracy'])
history = model.fit(x_train,y_train, batch_size=64,epochs=60,verbose=1,validation_data = (x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/60
# 80/80 [==============================] - 11s 114ms/step - loss: 2.2739 - accuracy: 0.1562 - val_loss: 2.2436 - val_accuracy: 0.1852
# Epoch 2/60
# 80/80 [==============================] - 9s 111ms/step - loss: 2.2330 - accuracy: 0.1892 - val_loss: 2.1946 - val_accuracy: 0.2274
# Epoch 3/60
# 80/80 [==============================] - 9s 111ms/step - loss: 2.1612 - accuracy: 0.2408 - val_loss: 2.1329 - val_accuracy: 0.2503
# Epoch 4/60
# 80/80 [==============================] - 9s 111ms/step - loss: 2.0883 - accuracy: 0.2600 - val_loss: 2.0572 - val_accuracy: 0.2638
# Epoch 5/60
# 80/80 [==============================] - 9s 111ms/step - loss: 2.0390 - accuracy: 0.2715 - val_loss: 2.0193 - val_accuracy: 0.2761
# Epoch 6/60
# 80/80 [==============================] - 9s 110ms/step - loss: 1.9711 - accuracy: 0.2926 - val_loss: 1.9669 - val_accuracy: 0.2978
# Epoch 7/60
# 80/80 [==============================] - 9s 111ms/step - loss: 1.9085 - accuracy: 0.3341 - val_loss: 1.9334 - val_accuracy: 0.3124
# Epoch 8/60
# 80/80 [==============================] - 9s 110ms/step - loss: 1.8068 - accuracy: 0.3726 - val_loss: 1.8542 - val_accuracy: 0.3505
# Epoch 9/60
# 80/80 [==============================] - 9s 111ms/step - loss: 1.7209 - accuracy: 0.4050 - val_loss: 1.8803 - val_accuracy: 0.3124
# Epoch 10/60
# 80/80 [==============================] - 9s 111ms/step - loss: 1.6263 - accuracy: 0.4418 - val_loss: 1.8358 - val_accuracy: 0.3669
# Epoch 11/60
# 80/80 [==============================] - 9s 110ms/step - loss: 1.5202 - accuracy: 0.4744 - val_loss: 1.7847 - val_accuracy: 0.3751
# Epoch 12/60
# Epoch 31/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0709 - accuracy: 0.9877 - val_loss: 3.0220 - val_accuracy: 0.4168
# Epoch 32/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0634 - accuracy: 0.9898 - val_loss: 3.0686 - val_accuracy: 0.4191
# Epoch 33/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0544 - accuracy: 0.9924 - val_loss: 3.1604 - val_accuracy: 0.4174
# Epoch 34/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0518 - accuracy: 0.9922 - val_loss: 3.1289 - val_accuracy: 0.4250
# Epoch 35/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0546 - accuracy: 0.9914 - val_loss: 3.2133 - val_accuracy: 0.4302
# Epoch 36/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0519 - accuracy: 0.9908 - val_loss: 3.3197 - val_accuracy: 0.4162
# Epoch 37/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0465 - accuracy: 0.9928 - val_loss: 3.3258 - val_accuracy: 0.4174
# Epoch 38/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0440 - accuracy: 0.9943 - val_loss: 3.3158 - val_accuracy: 0.4238
# Epoch 39/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0395 - accuracy: 0.9949 - val_loss: 3.3705 - val_accuracy: 0.4215
# Epoch 40/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0382 - accuracy: 0.9941 - val_loss: 3.3423 - val_accuracy: 0.4203
# Epoch 41/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0372 - accuracy: 0.9943 - val_loss: 3.3510 - val_accuracy: 0.4261
# Epoch 42/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0359 - accuracy: 0.9949 - val_loss: 3.4565 - val_accuracy: 0.4238
# Epoch 43/60
# 80/80 [==============================] - 9s 113ms/step - loss: 0.0331 - accuracy: 0.9953 - val_loss: 3.3875 - val_accuracy: 0.4297
# Epoch 44/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0327 - accuracy: 0.9953 - val_loss: 3.5191 - val_accuracy: 0.4279
# Epoch 45/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0317 - accuracy: 0.9955 - val_loss: 3.5792 - val_accuracy: 0.4256
# Epoch 46/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0322 - accuracy: 0.9953 - val_loss: 3.5755 - val_accuracy: 0.4197
# Epoch 47/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0286 - accuracy: 0.9957 - val_loss: 3.5814 - val_accuracy: 0.4191
# Epoch 48/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0264 - accuracy: 0.9967 - val_loss: 3.6300 - val_accuracy: 0.4291
# Epoch 49/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0270 - accuracy: 0.9965 - val_loss: 3.6203 - val_accuracy: 0.4297
# Epoch 50/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0277 - accuracy: 0.9961 - val_loss: 3.6500 - val_accuracy: 0.4273
# Epoch 51/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0272 - accuracy: 0.9965 - val_loss: 3.6368 - val_accuracy: 0.4273
# Epoch 52/60
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0235 - accuracy: 0.9971 - val_loss: 3.7958 - val_accuracy: 0.4261
# Epoch 53/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0253 - accuracy: 0.9967 - val_loss: 3.9397 - val_accuracy: 0.4138
# Epoch 54/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0245 - accuracy: 0.9969 - val_loss: 3.7523 - val_accuracy: 0.4355
# Epoch 55/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0253 - accuracy: 0.9967 - val_loss: 3.7652 - val_accuracy: 0.4273
# Epoch 56/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0235 - accuracy: 0.9969 - val_loss: 3.7470 - val_accuracy: 0.4373
# Epoch 57/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0250 - accuracy: 0.9967 - val_loss: 3.8962 - val_accuracy: 0.4185
# Epoch 58/60
# 80/80 [==============================] - 9s 112ms/step - loss: 0.0247 - accuracy: 0.9967 - val_loss: 3.7473 - val_accuracy: 0.4349
# Epoch 59/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0232 - accuracy: 0.9969 - val_loss: 3.8101 - val_accuracy: 0.4355
# Epoch 60/60
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0217 - accuracy: 0.9971 - val_loss: 3.8574 - val_accuracy: 0.4326

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'], loc='upper left')

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from google.colab.patches import cv2_imshow

img = load_img('bapxao.jpg', target_size=(150,150))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img/=255.0

a = np.argmax(model.predict(img), axis=-1)
print(model.predict(img))
print('ĐÂY LÀ',class_name[int(a)])
# Out:
# [[1.09829394e-04 8.88356124e-04 9.18809623e-02 9.03000474e-01
#   6.32325653e-04 5.35029631e-06 9.07949652e-06 3.46641196e-03
#   3.96787027e-06 3.21454195e-06]]
# ĐÂY LÀ bắp xào

# %%
img = load_img('bdmt.jpg', target_size=(150,150))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img/=255.0

a = np.argmax(model.predict(img), axis=-1)
print(model.predict(img))
print('ĐÂY LÀ',class_name[int(a)])
# Out:
# [[4.7122455e-07 8.9728972e-03 1.1191241e-07 9.8760090e-08 4.0806940e-06
#   6.2036594e-07 4.1936294e-04 3.8497639e-08 9.9059463e-01 7.6398692e-06]]
# ĐÂY LÀ bún đậu mắn tôm
